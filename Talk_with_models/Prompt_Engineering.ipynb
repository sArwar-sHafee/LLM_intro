# %% [markdown]
# # API Calling

# %% [markdown]
# ## Open AI

# %%
# %%capture
# !pip install openai

# %%
#@title Secrate Key

#@markdown **import os**

#@markdown **os.environ['OPENAI_API_KEY'] = "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXX"**

import os
os.environ['OPENAI_API_KEY'] = "Your API Key"

# %%
from openai import OpenAI
client = OpenAI()
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a poetic assistant, skilled in explaining complex programming concepts with creative flair."},
        {"role": "user", "content": "write a haiku about ai"}
    ]
)
print(completion.choices[0].message.content)
# Out:
# Lines of code entwined,
# Dreams born from silicon minds,
# Whispers of thought shine.

# %% [markdown]
# ## Gemini

# %%
# %%capture
# !pip install google-generativeai

# %%
#@title Secrate Key

#@markdown **import os**

#@markdown **os.environ['GEMINI_API_KEY'] = "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXX"**

import os
os.environ['GEMINI_API_KEY'] = "Your API Key"

# %%
import os
import google.generativeai as genai
genai.configure(api_key=os.environ["GEMINI_API_KEY"])

generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 64,
  "max_output_tokens": 8192,
  "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
  model_name="gemini-1.5-flash",
  generation_config=generation_config,
   system_instruction="You are a helpful assistant",
)

chat_session = model.start_chat(
  history=[
  ]
)

response = chat_session.send_message("Hello Gemini, I am shafee")

print(response.text)
# Out:
# Hello Shafee! 👋 It's nice to meet you. What can I do for you today? 😊

# %% [markdown]
# # Local Run

# %%
# %%capture
# !pip install -U transformers

# %% [markdown]
# ## Qwen

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2-0.5B-Instruct")
model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen2-0.5B-Instruct")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]
# ...

# %%
input_text = "Write a short story about spiderman"
input_ids = tokenizer.encode(input_text, return_tensors="pt")

output = model.generate(input_ids, max_length=256)

generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
print("-"*30 + "\n"+ generated_text + "\n" + "-"*30 )

# %% [markdown]
# ### Using GPU

# %%
#@title Huggingface Access Token

#@markdown **from huggingface_hub import login**

#@markdown **login(token="XXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")**

from huggingface_hub import login
login(token="Your Huggingface Access Token")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("google/gemma-2-2b-it")
model = AutoModelForCausalLM.from_pretrained("google/gemma-2-2b-it", device_map="cuda")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
input_text = "Write a short story about spiderman"
input_ids = tokenizer.encode(input_text, return_tensors="pt").to("cuda")

output = model.generate(input_ids, max_length=100)

generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
print(generated_text)
# Out:
# Write a short story about spiderman and his new girlfriend, a brilliant astrophysicist named Maya.
#
# *This story is about the web-slinger's journey of self-discovery and finding love in the most unexpected places.*
#
# The city lights blurred beneath him, a kaleidoscope of color against the inky canvas of the night. Spider-Man, perched atop a skyscraper, felt a familiar pang of loneliness. He was a hero, a protector, but sometimes, even the greatest of
